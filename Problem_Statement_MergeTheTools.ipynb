# %% [markdown]
# # Solving Python Problem DifficultyLevel Medium

# %% [markdown]
# ## Problem Statement

# %%
from IPython import display
display.Image(r"C:\Users\vishw\Desktop\prob_img.png")

# %%
display.Image(r"C:\Users\vishw\Desktop\prob_img2.png")

# %% [markdown]
# ## Solution

# %%
def f1(strng, k):
    a=len(strng)
    b=a/k    
    for i in range(0,a,k):        
        x=(strng[i:i+k])
        lst=list()
        lst.extend(x)
        lst_req=list()
        
        for i in lst:            
            if i not in lst_req:
                lst_req.append(i)   
                print(lst_req[len(lst_req)-1],end="")
        print()

# %%
f1("...",1246)
# Out:
# RDITWGZKCEXNHSAUJYOFQMPVBL
# DOVIKJPRGYHZQXBMEUALCTSWFN
# JBCLGFUSTDOKYIRZVAEXPWMQNH
# OQNIBFLHXZSRJMDETWGYVPUACK
# LBSTKUYVHMZQAXGJPCNOEWDIRF
# OYPZVRFKDEUQSIBAXGLJWMNCHT
# WRDSMQIGZXHEOBACFNVUKJPYTL
# EDQNUKVBRSLGWZOAMXIHJYCTFP

# %%
f1("ABACYUEYOOOO",3)
# Out:
# AB
# CYU
# EYO
# O

# %%
f1("AAAAABBBBBHHHHHOOOOOWWWWWPPPPP",5)
# Out:
# A
# B
# H
# O
# W
# P

# %%
f1("AAHAABBYBBHHHMHOOIOOWWMWWPPQPP",5)
# Out:
# AH
# BY
# HM
# OI
# WM
# PQ

# %%
f1("QAZAWSXWEDCERTYTOLKLYHNNUJJJ",4)
# Out:
# QAZ
# WSX
# EDC
# RTY
# OLK
# YHN
# UJ
